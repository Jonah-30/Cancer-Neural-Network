# %% [markdown]
# Import needed libraries and datasets.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Cancer AI/cancer.csv') 
dataset.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    diagnosis(1=m, 0=b)  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0                    1        17.99  ...          0.4601                  0.11890
# 1                    1        20.57  ...          0.2750                  0.08902
# 2                    1        19.69  ...          0.3613                  0.08758
# 3                    1        11.42  ...          0.6638                  0.17300
# 4                    1        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# Seperate the inputs and outputs in the dataset.

# %%
x = dataset.drop(columns = ["diagnosis(1=m, 0=b)"])
y = dataset["diagnosis(1=m, 0=b)"]

# %% [markdown]
# Split the data into a training dataset and a testing dataset.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Initialize neural network.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential()

# %% [markdown]
# Structure the neural network and set the neurons.

# %%
model.add(tf.keras.layers.Dense(256, input_shape = x_train.shape, activation='sigmoid'))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# Set up the back-propagation.

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Train the neural network.

# %%
model.fit(x_train, y_train, epochs=400)
# Out:
# Epoch 1/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9451
# Epoch 2/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9473
# Epoch 3/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9495
# Epoch 4/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9626
# Epoch 5/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9604
# Epoch 6/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9560
# Epoch 7/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9495
# Epoch 8/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9429
# Epoch 9/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9538
# Epoch 10/400
# ...

# %% [markdown]
# Use the trained neural network on the test data.

# %%
print(model.evaluate(x_test, y_test))
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9649
# [0.07778608053922653, 0.9649122953414917]
